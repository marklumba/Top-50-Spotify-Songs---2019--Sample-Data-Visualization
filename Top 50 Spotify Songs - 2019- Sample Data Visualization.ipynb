# %% [markdown]
# ## Top 50 Spotify Songs - 2019
# ### Top 50 songs listened in 2019 on spotify

# %% [markdown]
# Installing the required python libraries

# %%
# install the module using pip

# !pip install pandas
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Importing the required modules

# %%
# import the modules

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Load the data
# As you learned in the previous tutorial, we load the dataset using the pd.read_csv command.

# %%
# read csv file
top_50_filepath = r"C:\Users\IA-User\Documents\Python Projects\Data Analysis\top50.csv"
top_50 = pd.read_csv(top_50_filepath, encoding='Windows-1252')
top_50
# Out:
#                                            Track.Name       Artist.Name  \
# 0                                            Señorita      Shawn Mendes
# 1                                               China          Anuel AA
# 2                       boyfriend (with Social House)     Ariana Grande
# 3                     Beautiful People (feat. Khalid)        Ed Sheeran
# 4                         Goodbyes (Feat. Young Thug)       Post Malone
# 5                   I Don't Care (with Justin Bieber)        Ed Sheeran
# 6                                              Ransom         Lil Tecca
# 7                                   How Do You Sleep?         Sam Smith
# 8                               Old Town Road - Remix         Lil Nas X
# 9                                             bad guy     Billie Eilish
# 10                                           Callaita         Bad Bunny
# 11              Loco Contigo (feat. J. Balvin & Tyga)          DJ Snake
# ...

# %% [markdown]
# Examine the data
# We can print the first five rows of the dataset by using the head command.

# %%
# Print the first 5 rows of the data

top_50.head()
# Out:
#                         Track.Name    Artist.Name           Genre  \
# 0                         Señorita   Shawn Mendes    canadian pop
# 1                            China       Anuel AA  reggaeton flow
# 2    boyfriend (with Social House)  Ariana Grande       dance pop
# 3  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
#    Length.  Acousticness..  Speechiness.  Popularity
# ...

# %% [markdown]
# Check now that the first five rows agree with the image of the dataset (from when we saw what it would look like in Excel).
#
# Empty entries will appear as NaN, which is short for "Not a Number".
#
# We can also take a look at the last five rows of the data by making only one small change (where .head() becomes .tail()):

# %%
# Print the last five rows of the data

top_50.tail()
# Out:
#                                        Track.Name       Artist.Name    Genre  \
# 45                                One Thing Right        Marshmello  brostep
# 46                                      Te Robaré         Nicky Jam    latin
# 47                                        Happier        Marshmello  brostep
# 48                                  Call You Mine  The Chainsmokers      edm
# 49  Cross Me (feat. Chance the Rapper & PnB Rock)        Ed Sheeran      pop
#
#     Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  \
# 45                88      62            66              -2        58
# 46               176      75            67              -4         8
# 47               100      79            69              -3        17
# 48               104      70            59              -6        41
# 49                95      79            75              -6         7
#
#     Valence.  Length.  Acousticness..  Speechiness.  Popularity
# ...

# %% [markdown]
# Plot the data
# Now that the dataset is loaded into the notebook, we need only one line of code to make a line chart!

# %%
# Line chart showing Top 50 Spotify Songs - 2019 

sns.lineplot(data=top_50)
# Out:
# <AxesSubplot: >

# %% [markdown]
# As you can see above, the line of code is relatively short and has two main components:
#
# sns.lineplot tells the notebook that we want to create a line chart.
# Every command that you learn about in this practice tutoria will start with sns, which indicates that the command comes from the seaborn package. For instance, we use sns.lineplot to make line charts. Soon, you'll learn that we use sns.barplot and sns.heatmap to make bar charts and heatmaps, respectively.
# data=spotify_data selects the data that will be used to create the chart.
# Note that you will always use this same format when you create a line chart, and the only thing that changes with a new dataset is the name of the dataset. So, if you were working with a different dataset named financial_data, for instance, the line of code would appear as follows:
#
# sns.lineplot(data=financial_data)
# Sometimes there are additional details we'd like to modify, like the size of the figure and the title of the chart. Each of these options can easily be set with a single line of code.

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,6))

# Add title
plt.title("Top 50 Spotify Songs - 2019")

# Line chart showing Top 50 Spotify Songs - 2019 
sns.lineplot(data=top_50)
# Out:
# <AxesSubplot: title={'center': 'Top 50 Spotify Songs - 2019'}>

# %% [markdown]
# The first line of code sets the size of the figure to 14 inches (in width) by 6 inches (in height). To set the size of any figure, you need only copy the same line of code as it appears. Then, if you'd like to use a custom size, change the provided values of 14 and 6 to the desired width and height.
#
# The second line of code sets the title of the figure. Note that the title must always be enclosed in quotation marks ("...")!

# %% [markdown]
# Plot a subset of the data
# So far, you've learned how to plot a line for every column in the dataset. In this section, you'll learn how to plot a subset of the columns.
#
# We'll begin by printing the names of all columns. This is done with one line of code and can be adapted for any dataset by just swapping out the name of the dataset (in this case, top_50).

# %%
list(top_50.columns)
# Out:
# ['Track.Name',
#  'Artist.Name',
#  'Genre',
#  'Beats.Per.Minute',
#  'Energy',
#  'Danceability',
#  'Loudness..dB..',
#  'Liveness',
#  'Valence.',
#  'Length.',
#  'Acousticness..',
#  'Speechiness.',
#  'Popularity']

# %% [markdown]
# In the next code cell, we plot the lines corresponding to the first two columns in the dataset.

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,6))

# Add title
plt.title("Top 50 Spotify Songs - 2019")

# Line chart showing the high interms of Beats.Per.Minute
sns.lineplot(data=top_50['Beats.Per.Minute'], label="Beats.Per.Minute")

# Line chart showing the high interms of Energy
sns.lineplot(data=top_50['Energy'], label="Energy")

# Add label for horizontal axis
plt.xlabel("Track Name")
# Out:
# Text(0.5, 0, 'Track Name')

# %% [markdown]
# The first two lines of code set the title and size of the figure (and should look very familiar!).
#
#
# The next two lines each add a line to the line chart. For instance, consider the first one, which adds the line for "Beats.Per.Minute
# ":
#
# Line chart showing the high value of Beats.Per.Minute and Energy per each song'
# sns.lineplot(data=top_50['Beats.Per.Minute'], label="Beats.Per.Minute")
# This line looks really similar to the code we used when we plotted every line in the dataset, but it has a few key differences:
#
# Instead of setting data=top_50, we set data=top_50['Beats.Per.Minute']. In general, to plot only a single column, we use this format with putting the name of the column in single quotes and enclosing it in square brackets. (To make sure that you correctly specify the name of the column, you can print the list of all column names using the command you learned above.)
# We also add label="Beats.Per.Minute" to make the line appear in the legend and set its corresponding label.
# The final line of code modifies the label for the horizontal axis (or x-axis), where the desired label is placed in quotation marks ("...").
